# %%
# for coloab only
from google.colab import drive
drive.mount('/content/gdrive')

# %%
#!ls /content/gdrive/My\ Drive/ssd_workspace/nd880_AI_for_trading/lessons/term2/lesson_10_deep_learning_with_pytroch/pytorch-example/intro-to-pytorch
# !ls /content/gdrive/My\ Drive/ssd_workspace/nd880_AI_for_trading/lessons/term2/lesson_10_deep_learning_with_pytroch/pytorch-example/
# Out:
# ls: cannot access '/content/gdrive/My Drive/ssd_workspace/nd880_AI_for_trading/lessons/term2/lesson_10_deep_learning_with_pytroch/pytorch-example/': No such file or directory
